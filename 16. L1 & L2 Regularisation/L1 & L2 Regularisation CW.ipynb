# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Melbourne_housing_FULL.csv')
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 0  3/09/2016       2.5    3067.0      ...            1.0  1.0     126.0
# 1  3/12/2016       2.5    3067.0      ...            1.0  1.0     202.0
# 2  4/02/2016       2.5    3067.0      ...            1.0  0.0     156.0
# 3  4/02/2016       2.5    3067.0      ...            2.0  1.0       0.0
# 4  4/03/2017       2.5    3067.0      ...            2.0  0.0     134.0
#
#    BuildingArea  YearBuilt         CouncilArea Lattitude  Longtitude  \
# ...

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
colt_use = ['Suburb','Rooms','Type','Price','Method','SellerG', 'Regionname',
            'Propertycount', 'Distance', 'CouncilArea', 'Bedroom2', 'Bathroom',
            'Car', 'Landsize', 'BuildingArea']
ds = df[colt_use]
ds
# Out:
#                    Suburb  Rooms Type      Price Method        SellerG  \
# 0              Abbotsford      2    h        NaN     SS         Jellis
# 1              Abbotsford      2    h  1480000.0      S         Biggin
# 2              Abbotsford      2    h  1035000.0      S         Biggin
# 3              Abbotsford      3    u        NaN     VB         Rounds
# 4              Abbotsford      3    h  1465000.0     SP         Biggin
# 5              Abbotsford      3    h   850000.0     PI         Biggin
# 6              Abbotsford      4    h  1600000.0     VB         Nelson
# 7              Abbotsford      4    h        NaN     SN         Nelson
# 8              Abbotsford      2    h        NaN      S         Biggin
# 9              Abbotsford      2    h        NaN      S        Collins
# 10             Abbotsford      2    h   941000.0      S         Jellis
# 11             Abbotsford      3    h  1876000.0      S         Nelson
# ...

# %%
ds.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        3
# Distance             1
# CouncilArea          3
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# dtype: int64

# %%
cols_tofill_zero = ['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']
ds[cols_tofill_zero] = ds[cols_tofill_zero].fillna(0)
ds
# Out:
#                    Suburb  Rooms Type      Price Method        SellerG  \
# 0              Abbotsford      2    h        NaN     SS         Jellis
# 1              Abbotsford      2    h  1480000.0      S         Biggin
# 2              Abbotsford      2    h  1035000.0      S         Biggin
# 3              Abbotsford      3    u        NaN     VB         Rounds
# 4              Abbotsford      3    h  1465000.0     SP         Biggin
# 5              Abbotsford      3    h   850000.0     PI         Biggin
# 6              Abbotsford      4    h  1600000.0     VB         Nelson
# 7              Abbotsford      4    h        NaN     SN         Nelson
# 8              Abbotsford      2    h        NaN      S         Biggin
# 9              Abbotsford      2    h        NaN      S        Collins
# 10             Abbotsford      2    h   941000.0      S         Jellis
# 11             Abbotsford      3    h  1876000.0      S         Nelson
# ...

# %%
ds.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        0
# Distance             0
# CouncilArea          3
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# dtype: int64

# %%
ds['Landsize'] = ds['Landsize'].fillna(ds.Landsize.mean())
ds['BuildingArea'] = ds['BuildingArea'].fillna(ds.BuildingArea.mean())

# %%
ds.isna().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Price            7610
# Method              0
# SellerG             0
# Regionname          3
# Propertycount       0
# Distance            0
# CouncilArea         3
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# dtype: int64

# %%
ds.dropna(inplace=True)
ds.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# dtype: int64

# %%
ds.shape
# Out:
# (27244, 15)

# %%
ds
# Out:
#                    Suburb  Rooms Type      Price Method        SellerG  \
# 1              Abbotsford      2    h  1480000.0      S         Biggin
# 2              Abbotsford      2    h  1035000.0      S         Biggin
# 4              Abbotsford      3    h  1465000.0     SP         Biggin
# 5              Abbotsford      3    h   850000.0     PI         Biggin
# 6              Abbotsford      4    h  1600000.0     VB         Nelson
# 10             Abbotsford      2    h   941000.0      S         Jellis
# 11             Abbotsford      3    h  1876000.0      S         Nelson
# 14             Abbotsford      2    h  1636000.0      S         Nelson
# 15             Abbotsford      3    h  1000000.0      S         Jellis
# 16             Abbotsford      2    t   745000.0      S         Jellis
# 17             Abbotsford      1    u   300000.0      S         Biggin
# 18             Abbotsford      2    h  1097000.0      S         Biggin
# ...

# %%
ds = pd.get_dummies(ds, drop_first=True)
ds.head()
# Out:
#    Rooms      Price  Propertycount  Distance  Bedroom2  Bathroom  Car  \
# 1      2  1480000.0         4019.0       2.5       2.0       1.0  1.0
# 2      2  1035000.0         4019.0       2.5       2.0       1.0  0.0
# 4      3  1465000.0         4019.0       2.5       3.0       2.0  0.0
# 5      3   850000.0         4019.0       2.5       3.0       2.0  1.0
# 6      4  1600000.0         4019.0       2.5       3.0       1.0  2.0
#
#    Landsize  BuildingArea  Suburb_Aberfeldie  \
# 1     202.0      160.2564                  0
# 2     156.0       79.0000                  0
# 4     134.0      150.0000                  0
# 5      94.0      160.2564                  0
# 6     120.0      142.0000                  0
#
#                     ...                    \
# 1                   ...
# 2                   ...
# 4                   ...
# 5                   ...
# 6                   ...
#
#    CouncilArea_Moorabool Shire Council  CouncilArea_Moreland City Council  \
# ...

# %%
X = ds.drop('Price', axis =1)
y = ds['Price']

# %%
from sklearn.model_selection import train_test_split
X_tr, X_te, y_tr, y_te = train_test_split(X,y, test_size= 0.3, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_tr, y_tr)

# %%
reg.score(X_te, y_te)
# Out:
# 0.13853683161510377

# %%
reg.score(X_tr, y_tr)
# Out:
# 0.6827792395792723

# %%
from sklearn import linear_model
las_reg = linear_model.Lasso(alpha=50, max_iter=100, tol=0.1)
las_reg.fit(X_tr, y_tr)
# Out:
# Lasso(alpha=50, copy_X=True, fit_intercept=True, max_iter=100,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.1, warm_start=False)

# %%
las_reg.score(X_te, y_te)
# Out:
# 0.6636111369404487

# %%
las_reg.score(X_tr, y_tr)
# Out:
# 0.6766985624766824

# %%
rid_reg = linear_model.Ridge(alpha=50, max_iter=100, tol=0.1)
rid_reg.fit(X_tr, y_tr)
# Out:
# Ridge(alpha=50, copy_X=True, fit_intercept=True, max_iter=100,
#    normalize=False, random_state=None, solver='auto', tol=0.1)

# %%
rid_reg.score(X_te, y_te)
# Out:
# 0.6670848945194957

# %%
rid_reg.score(X_tr, y_tr)
# Out:
# 0.6622376739684328
